# %% [markdown]
# <a href="https://colab.research.google.com/github/korhankoz/so_survey_analysis/blob/main/SO_SURVEY_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#sd
print('sa')
# Out:
# sa
